# %% [markdown]
# What is Reinforcement Learning (RL)?
# Reinforcement Learning (RL) is a type of machine learning where an agent learns by interacting with an environment.
#
# The agent takes actions in the environment.
#
# The environment provides feedback in the form of rewards or penalties.
#
# The goal of the agent is to maximize the total reward over time by learning the best strategy (called a policy).

# %%
import random

# States (positions)
states = list(range(1, 6))  # Positions: 1 to 5
goal = 5

# Actions
actions = ["left", "right"]

# Agent training
for episode in range(5):
    position = random.choice(states)
    print(f"Episode {episode+1}: Start at position {position}")
    
    steps = 0
    while position != goal:
        action = random.choice(actions)
        if action == "right":
            position = min(goal, position + 1)
        else:
            position = max(1, position - 1)
        steps += 1
        print(f"  Step {steps}: Move {action}, now at {position}")
    print(f"Reached the goal in {steps} steps!\n")
# Out:
# Episode 1: Start at position 4
#   Step 1: Move left, now at 3
#   Step 2: Move right, now at 4
#   Step 3: Move left, now at 3
#   Step 4: Move right, now at 4
#   Step 5: Move left, now at 3
#   Step 6: Move right, now at 4
#   Step 7: Move left, now at 3
#   Step 8: Move left, now at 2
#   Step 9: Move right, now at 3
#   Step 10: Move left, now at 2
#   Step 11: Move left, now at 1
#   Step 12: Move left, now at 1
#   Step 13: Move right, now at 2
#   Step 14: Move left, now at 1
#   Step 15: Move left, now at 1
#   Step 16: Move left, now at 1
#   Step 17: Move right, now at 2
#   Step 18: Move left, now at 1
#   Step 19: Move right, now at 2
#   Step 20: Move right, now at 3
#   Step 21: Move right, now at 4
#   Step 22: Move right, now at 5
# Reached the goal in 22 steps!
#
# Episode 2: Start at position 2
#   Step 1: Move right, now at 3
#   Step 2: Move left, now at 2
#   Step 3: Move right, now at 3
#   Step 4: Move right, now at 4
#   Step 5: Move right, now at 5
# ...
