# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %%
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df = df[df['IMDb']>6.0]

# %%
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 2                   2024   8.4
# 4                    585   7.0
# 5                    111   8.3
# 6                    180   7.5
# 7                    475   6.5
# ...

# %%
df.to_csv('new_data.csv', index = False)

# %%
df3 = pd.read_json("data.json")

# %%
df
# Out:
#    id             name   age gender           program registration_date  \
# 0   1    Mohammad Khan  30.0      M  Computer Science        2023-09-01
# 1   2  Abdullah Rahman  22.0      M       Mathematics        2023-09-01
# 2   3     Najifa Ahmed  21.0      F           Physics        2023-09-01
# 3   4       Dina Islam  19.0      F         Chemistry        2023-09-01
# 4   5     Tasnim Begum   NaN      F           Biology        2023-09-01
#
#       status                                           projects
# 0     Active  {'name': 'Image Editor v1', 'last_edited_image...
# 1     Active  {'name': 'Photo Filter App', 'last_edited_imag...
# 2    Dropped  {'name': None, 'last_edited_image': None, 'edi...
# 3  Graduated  {'name': 'Image Crop Tool', 'last_edited_image...
# 4     Active  {'name': 'Background Remover', 'last_edited_im...

# %%
data = [
    {
        "id": 1,
        "name": "Mohammad Khan",
        "age": 30,
        "gender": "M",
        "program": "Computer Science",
        "registration_date": "2023-09-01",
        "status": "Active",
        "projects": {
            "name": "Image Editor v1",
            "last_edited_image": "landscape.jpg",
            "edits_applied": ["resize", "rotate", "grayscale"],
            "last_modified": "2025-05-15T10:30:00Z"
        }
    },
    {
        "id": 2,
        "name": "Abdullah Rahman",
        "age": 22,
        "gender": "M",
        "program": "Mathematics",
        "registration_date": "2023-09-01",
        "status": "Active",
        "projects": {
            "name": "Photo Filter App",
            "last_edited_image": "portrait.png",
            "edits_applied": ["blur", "brightness"],
            "last_modified": "2025-05-18T14:20:00Z"
        }
    }
]

# %%
df = pd.json_normalize(data)

# %%
df
# Out:
#    id             name  age gender           program registration_date  \
# 0   1    Mohammad Khan   30      M  Computer Science        2023-09-01
# 1   2  Abdullah Rahman   22      M       Mathematics        2023-09-01
#
#    status     projects.name projects.last_edited_image  \
# 0  Active   Image Editor v1              landscape.jpg
# 1  Active  Photo Filter App               portrait.png
#
#         projects.edits_applied projects.last_modified
# 0  [resize, rotate, grayscale]   2025-05-15T10:30:00Z
# 1           [blur, brightness]   2025-05-18T14:20:00Z
