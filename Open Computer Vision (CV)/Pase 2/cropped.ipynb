# %%
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread("girlImage.jpg")

# %%
cropped = image[200:400, 350:600]

# %%
plt_image_rgb = cv2.cvtColor(cropped, cv2.COLOR_BGR2RGB)

# %%
# image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
# cv2.imshow("Cropped Image Display", cropped) # "Cropped Image Display" is the window name
# cv2.waitKey(0) # Waits indefinitely for a key press
# cv2.destroyAllWindows() # Closes all OpenCV windows

# %%
plt.imshow(plt_image_rgb)
