# %%
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread("girlImage2.jpg")

# %%
image_Gary = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
image_rgb = cv2.cvtColor(image_Gary, cv2.COLOR_GRAY2RGB)

# %%
print(f"Image shape: {image_rgb.shape}")
# Out:
# Image shape: (738, 736, 3)

# %%
plt.imshow(image_rgb)
imageWrite = cv2.imwrite("newImage.png", image_Gary)

# %%
resized = cv2.resize(image_rgb, (330, 330))

# %%
plt.imshow(resized)

# %%
gray_image = cv2.imread('newImage.png', cv2.IMREAD_GRAYSCALE)
plt.imshow(gray_image)

# %%
# Convert to color image (BGR format)
color_image = cv2.cvtColor(gray_image, cv2.COLOR_GRAY2BGR)
plt.imshow(color_image)

# %%
# Alternatively, convert to RGB format
color_image_rgb = cv2.cvtColor(gray_image, cv2.COLOR_GRAY2RGB)
plt.imshow(color_image_rgb)

# %%
import numpy as np

# %%
resizedImg = cv2.resize(color_image_rgb, (300, 300))

# %%
arr = np.asarray(resizedImg)

# %%
arr[1][1]

for i in range(len(arr)):
    for j in range(len(arr)):
            arr[i][j] = arr[i][j] + np.random.randint(0,20)

# %%
arr[1][1]
# Out:
# array([87, 87, 87], dtype=uint8)

# %%
plt.imshow(arr)
plt.show()
