# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
image = cv2.imread("catgojop.jpg")
plt_image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
cv2.circle(plt_image_rgb, (300, 300), 200, (255,0,0), 3)
plt.imshow(plt_image_rgb)
