# %%
import seaborn as sns

# %%
sns.set_theme(style='darkgrid')

# %%
import numpy as np

# %%
x = np.random.randint(10, 100, size=15)

# %%
x
# Out:
# array([73, 42, 36, 97, 79, 80, 57, 38, 64, 10, 40, 15, 91, 65, 71])

# %%
y = np.sin(x)

# %%
y
# Out:
# array([-0.67677196, -0.91652155, -0.99177885,  0.37960774, -0.44411267,
#        -0.99388865,  0.43616476,  0.29636858,  0.92002604, -0.54402111,
#         0.74511316,  0.65028784,  0.10598751,  0.82682868,  0.95105465])

# %%
sns.lineplot(x=x, y=y)
# Out:
# <Axes: >
